# %%
from regression import*

# %%
def load_predict_model(setting, target):
    # Model
    result_folder = '../results/' + setting + '_' + target 
    model = load_model(result_folder +'/model')

    # Predict
    _, test_data = get_data(setting, target)
    predictions = predict_data(model, test_data)
    with open( result_folder + '/predictions.pkl', 'wb') as f: pickle.dump(predictions, f)

    metrics = evaluate(predictions)
    for key, value in metrics.items(): print(key, '=', round(np.median(value),3) )

    if target == 'r': y_label = 'Distance'
    else: y_label = target.upper()
        
    for n, prediction in enumerate(predictions):
        fig = plt.figure()
        ax = plt.subplot(111)    
        ax.plot(prediction.y_true*100, label='Target')
        ax.plot(prediction.y_pred*100, label='Prediction')            
        ax.legend()
        ax.grid(False)
        plt.xlabel('Time (s)')
        plt.ylabel(y_label + ' (cm)')
        plt.show()
        fig.savefig(result_folder + '/plots/'+ str(n) +'.png', bbox_inches='tight')

# %% [markdown]
# #### Single Node - Distance

# %%
load_predict_model(
    setting = 'single', 
    target = 'r')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# RMSE = 0.033
# R2 = 0.805
# MAPE = 0.067

# %% [markdown]
# #### Single Node - Z

# %%
load_predict_model(
    setting = 'single', 
    target = 'z')

# %% [markdown]
# #### Parallel - Distance

# %%
load_predict_model(
    setting = 'parallel', 
    target = 'r')

# %% [markdown]
# #### Parallel - z

# %%
load_predict_model(
    setting = 'parallel', 
    target = 'z')

# %% [markdown]
# #### Orthogonal - Distance

# %%
load_predict_model(
    setting = 'orthogonal', 
    target = 'r')

# %% [markdown]
# #### Orthogonal - Z

# %%
load_predict_model(
    setting = 'orthogonal', 
    target = 'z')
