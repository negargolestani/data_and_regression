# %%
from regression import*
# Out:
# Using TensorFlow backend.

# %%
models_name = ['lr','knn','dt','rf','et','mlp','lightgbm','catboost']

# %% [markdown]
# ## Single Sensor

# %%
train_data,_ = get_data(setting='single', target='r')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_f0999e6c_1269_11eb_94b6_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='single', target='x')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_4072d8b8_1270_11eb_a968_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='single', target='y')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_11bf27d4_1276_11eb_9030_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='single', target='z')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_467076d2_127e_11eb_afe1_0c7a150aaf09 th {
#           text-align: left;
# ...

# %% [markdown]
# ## Parallel

# %%
train_data,_ = get_data(setting='parallel', target='r')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_c97f2ed4_1247_11eb_93af_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='parallel', target='x')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_0032927e_11e3_11eb_8476_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='parallel', target='y')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_af22d26e_11e9_11eb_8534_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='parallel', target='z')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_73573e90_11f0_11eb_a9a9_0c7a150aaf09 th {
#           text-align: left;
# ...

# %% [markdown]
# ## Orthogonal

# %%
train_data,_ = get_data(setting='orthogonal', target='r')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_01715b46_11fc_11eb_a74e_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='orthogonal', target='x')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_63c42bb8_1203_11eb_a782_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='orthogonal', target='y')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_0f916034_1242_11eb_befa_0c7a150aaf09 th {
#           text-align: left;
# ...

# %%
train_data,_ = get_data(setting='orthogonal', target='z')
exp_reg = setup(train_data,
                train_size = .7,
                target = 'target', 
                normalize = True, 
                silent = True,
                verbose = False,
                session_id = 0)  

compare_models(include = models_name, round=3)
# Out:
# <style  type="text/css" >
#     #T_d25878e2_124f_11eb_bdcc_0c7a150aaf09 th {
#           text-align: left;
# ...
